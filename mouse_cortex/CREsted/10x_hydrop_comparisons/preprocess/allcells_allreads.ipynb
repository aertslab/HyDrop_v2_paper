# %% [markdown]
# # Inspect and preprocess data to anndata objects

# %%
import os
import crested
from _train_val_split import split_by_chromosome_folds

import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

print(crested.__version__)

# %%
data_root = "../../../../../../../data/paper_zips/10x_hydropv2_comparisons_data/" # set data root to the unzipped folder's data location
bigwigs_root = f"{data_root}/bigwigs/"
experiment = "allcells_allreads"
k_folds = 10
genome_file = "../../../../../../../data/genomes/refdata-cellranger-arc-mm10-2020-A-2.0.0/fasta/genome.fa"
consensus_regions_file = f"{data_root}/consensus_regions_mouse_cleanup_annot_all_data_fulldepth.bed"

# %%
genome = crested.Genome(
    genome_file,
    name="mm10"
)
crested.register_genome(genome)
# Out:
# 2025-06-18T17:25:38.425704+0200 INFO Genome mm10 registered.

# %% [markdown]
# ## 10x

# %%
bigwigs_folder = os.path.join(bigwigs_root, "10x_allcells_allreads")

# %%
adata = crested.import_bigwigs(
    bigwigs_folder=bigwigs_folder,
    regions_file=consensus_regions_file,
    target_region_width=1000,  
    target="mean",  
)
adata
# Out:
# 2025-06-18T17:25:56.335175+0200 INFO Extracting values from 16 bigWig files...
# AnnData object with n_obs × n_vars = 16 × 808845
#     obs: 'file_path'
#     var: 'chr', 'start', 'end'

# %%
adata.obs_names = adata.obs_names.str.split("___").str[0]
adata.obs_names
# Out:
# Index(['Astro', 'Endo_VLMC', 'L2_3_IT', 'L5_6_NP', 'L5_ET', 'L5_IT', 'L6_CT',
#        'L6_IT', 'L6b', 'Lamp5', 'Micro_PVM', 'OPC', 'Oligo', 'Pvalb',
#        'Sncg_Vip', 'Sst'],
#       dtype='object')

# %%
# add folds columns to adata.var
split_by_chromosome_folds(adata, k=k_folds)

# %%
adata.var
# Out:
#                        chr    start      end fold_0 fold_1 fold_2 fold_3  \
# region
# chr1:3094286-3094786  chr1  3094286  3094786    val  train  train  train
# chr1:3097001-3097501  chr1  3097001  3097501    val  train  train  train
# chr1:3097804-3098304  chr1  3097804  3098304    val  train  train  train
# chr1:3112437-3112937  chr1  3112437  3112937    val  train  train  train
# chr1:3118739-3119239  chr1  3118739  3119239    val  train  train  train
# ...                    ...      ...      ...    ...    ...    ...    ...
# chrY:1050180-1050680  chrY  1050180  1050680    val  train  train  train
# chrY:872845-873345    chrY   872845   873345  train    val  train  train
# chrY:1245537-1246037  chrY  1245537  1246037  train  train    val  train
# chrY:1010312-1010812  chrY  1010312  1010812  train  train  train    val
# chrY:897284-897784    chrY   897284   897784  train  train  train  train
#
#                      fold_4 fold_5 fold_6 fold_7 fold_8 fold_9
# region
# chr1:3094286-3094786  train  train  train  train  train  train
# chr1:3097001-3097501  train  train  train  train  train  train
# chr1:3097804-3098304  train  train  train  train  train  train
# chr1:3112437-3112937  train  train  train  train  train  train
# chr1:3118739-3119239  train  train  train  train  train  train
# ...                     ...    ...    ...    ...    ...    ...
# chrY:1050180-1050680  train  train  train  train  train  train
# chrY:872845-873345    train  train  train  train  train  train
# chrY:1245537-1246037  train  train  train  train  train  train
# chrY:1010312-1010812  train  train  train  train  train  train
# chrY:897284-897784      val  train  train  train  train  train
#
# [808845 rows x 13 columns]

# %%
adata.var['fold_0'].value_counts()
# Out:
# fold_0
# train    727952
# val       80893
# Name: count, dtype: int64

# %%
adata.var[(adata.var['chr'] == 'chr1')]['fold_0'].value_counts()
# Out:
# fold_0
# train    51777
# val       5753
# Name: count, dtype: int64

# %%
crested.pp.change_regions_width(
    adata,
    2114,
)
# Out:
# 2025-06-18T17:27:32.673948+0200 WARNING Region chrM:-362-1752 with coordinates chrM:-362-1752 is out of bounds for chromosome chrM. Removing region.
# 2025-06-18T17:27:32.714170+0200 WARNING Region chrM:14601-16715 with coordinates chrM:14601-16715 is out of bounds for chromosome chrM. Removing region.

# %%
crested.pp.normalize_peaks(
    adata, top_k_percent=0.03
)
# Out:
# 2025-06-18T17:27:49.960361+0200 INFO Filtering on top k Gini scores...
# 2025-06-18T17:27:57.692327+0200 INFO Added normalization weights to adata.obsm['weights']...
#                              chr      start        end fold_0 fold_1 fold_2  \
# region
# chr8:11634768-11636882      chr8   11634768   11636882  train  train  train
# chr19:23859508-23861622    chr19   23859508   23861622  train  train  train
# chr5:52474811-52476925      chr5   52474811   52476925  train  train  train
# chr19:23880009-23882123    chr19   23880009   23882123  train  train  train
# chr19:23960645-23962759    chr19   23960645   23962759  train  train  train
# ...                          ...        ...        ...    ...    ...    ...
# chr11:105869242-105871356  chr11  105869242  105871356  train  train  train
# chr8:3219471-3221585        chr8    3219471    3221585  train  train  train
# chr8:3492888-3495002        chr8    3492888    3495002  train  train  train
# chr1:43473319-43475433      chr1   43473319   43475433  train  train  train
# chr8:10979034-10981148      chr8   10979034   10981148  train  train  train
#
#                           fold_3 fold_4 fold_5 fold_6 fold_7 fold_8 fold_9
# region
# chr8:11634768-11636882     train  train  train  train    val  train  train
# chr19:23859508-23861622    train  train    val  train  train  train  train
# chr5:52474811-52476925     train  train  train  train  train  train    val
# chr19:23880009-23882123    train  train    val  train  train  train  train
# chr19:23960645-23962759    train  train    val  train  train  train  train
# ...                          ...    ...    ...    ...    ...    ...    ...
# chr11:105869242-105871356  train  train  train    val  train  train  train
# chr8:3219471-3221585       train  train  train  train    val  train  train
# chr8:3492888-3495002       train  train  train  train    val  train  train
# chr1:43473319-43475433     train    val  train  train  train  train  train
# chr8:10979034-10981148     train  train  train  train    val  train  train
#
# [55361 rows x 13 columns]

# %%
# %matplotlib inline
crested.pl.bar.normalization_weights(
    adata, title="Normalization Weights per Cell Type", x_label_rotation=90
)

# %%
outdir = f"../data/{experiment}/10x/"
os.makedirs(outdir, exist_ok=True)
adata.write_h5ad(os.path.join(outdir, "normalized.h5ad"))

# %%
crested.pp.filter_regions_on_specificity(adata, gini_std_threshold=1.0)
# Out:
# 2025-06-18T17:28:15.274914+0200 INFO After specificity filtering, kept 127944 out of 808843 regions.

# %%
adata.write_h5ad(os.path.join(outdir, "normalized_specific.h5ad"))

# %%
# specific peaks heatmap
crested.pl.heatmap.correlations_self(
    adata,
    title="Self Correlation Heatmap - 10x",
    x_label_rotation=90,
    width=8,
    height=8,
    vmax=1,
    log_transform=False,
    vmin=0.0,
)

# %% [markdown]
# ## HydropV2

# %%
bigwigs_folder = os.path.join(bigwigs_root, "hydrop_allcells_allreads")

# %%
adata = crested.import_bigwigs(
    bigwigs_folder=bigwigs_folder,
    regions_file=consensus_regions_file,
    target_region_width=1000,  
    target="mean",  
)
adata
# Out:
# 2025-06-18T17:28:32.774497+0200 INFO Extracting values from 16 bigWig files...
# AnnData object with n_obs × n_vars = 16 × 808845
#     obs: 'file_path'
#     var: 'chr', 'start', 'end'

# %%
adata.obs_names = adata.obs_names.str.split("___").str[0]
adata.obs_names
# Out:
# Index(['Astro', 'Endo_VLMC', 'L2_3_IT', 'L5_6_NP', 'L5_ET', 'L5_IT', 'L6_CT',
#        'L6_IT', 'L6b', 'Lamp5', 'Micro_PVM', 'OPC', 'Oligo', 'Pvalb',
#        'Sncg_Vip', 'Sst'],
#       dtype='object')

# %%
# add folds columns to adata.var
split_by_chromosome_folds(adata, k=k_folds)

# %%
adata.var
# Out:
#                        chr    start      end fold_0 fold_1 fold_2 fold_3  \
# region
# chr1:3094286-3094786  chr1  3094286  3094786    val  train  train  train
# chr1:3097001-3097501  chr1  3097001  3097501    val  train  train  train
# chr1:3097804-3098304  chr1  3097804  3098304    val  train  train  train
# chr1:3112437-3112937  chr1  3112437  3112937    val  train  train  train
# chr1:3118739-3119239  chr1  3118739  3119239    val  train  train  train
# ...                    ...      ...      ...    ...    ...    ...    ...
# chrY:1050180-1050680  chrY  1050180  1050680    val  train  train  train
# chrY:872845-873345    chrY   872845   873345  train    val  train  train
# chrY:1245537-1246037  chrY  1245537  1246037  train  train    val  train
# chrY:1010312-1010812  chrY  1010312  1010812  train  train  train    val
# chrY:897284-897784    chrY   897284   897784  train  train  train  train
#
#                      fold_4 fold_5 fold_6 fold_7 fold_8 fold_9
# region
# chr1:3094286-3094786  train  train  train  train  train  train
# chr1:3097001-3097501  train  train  train  train  train  train
# chr1:3097804-3098304  train  train  train  train  train  train
# chr1:3112437-3112937  train  train  train  train  train  train
# chr1:3118739-3119239  train  train  train  train  train  train
# ...                     ...    ...    ...    ...    ...    ...
# chrY:1050180-1050680  train  train  train  train  train  train
# chrY:872845-873345    train  train  train  train  train  train
# chrY:1245537-1246037  train  train  train  train  train  train
# chrY:1010312-1010812  train  train  train  train  train  train
# chrY:897284-897784      val  train  train  train  train  train
#
# [808845 rows x 13 columns]

# %%
adata.var['fold_0'].value_counts()
# Out:
# fold_0
# train    727952
# val       80893
# Name: count, dtype: int64

# %%
adata.var[(adata.var['chr'] == 'chr1')]['fold_0'].value_counts()
# Out:
# fold_0
# train    51777
# val       5753
# Name: count, dtype: int64

# %%
crested.pp.change_regions_width(
    adata,
    2114,
)
# Out:
# 2025-06-18T17:30:16.789817+0200 WARNING Region chrM:-362-1752 with coordinates chrM:-362-1752 is out of bounds for chromosome chrM. Removing region.
# 2025-06-18T17:30:16.824981+0200 WARNING Region chrM:14601-16715 with coordinates chrM:14601-16715 is out of bounds for chromosome chrM. Removing region.

# %%
crested.pp.normalize_peaks(
    adata, top_k_percent=0.03
)
# Out:
# 2025-06-18T17:30:34.191459+0200 INFO Filtering on top k Gini scores...
# 2025-06-18T17:30:42.103450+0200 INFO Added normalization weights to adata.obsm['weights']...
#                            chr     start       end fold_0 fold_1 fold_2  \
# region
# chr8:11634768-11636882    chr8  11634768  11636882  train  train  train
# chr19:23859508-23861622  chr19  23859508  23861622  train  train  train
# chr19:23960645-23962759  chr19  23960645  23962759  train  train  train
# chr8:12792429-12794543    chr8  12792429  12794543  train  train  train
# chr8:13629041-13631155    chr8  13629041  13631155  train  train  train
# ...                        ...       ...       ...    ...    ...    ...
# chr19:23174666-23176780  chr19  23174666  23176780  train  train  train
# chr15:86727364-86729478  chr15  86727364  86729478  train  train    val
# chr19:23760587-23762701  chr19  23760587  23762701  train  train  train
# chr8:4165702-4167816      chr8   4165702   4167816  train  train  train
# chr8:10925678-10927792    chr8  10925678  10927792  train  train  train
#
#                         fold_3 fold_4 fold_5 fold_6 fold_7 fold_8 fold_9
# region
# chr8:11634768-11636882   train  train  train  train    val  train  train
# chr19:23859508-23861622  train  train    val  train  train  train  train
# chr19:23960645-23962759  train  train    val  train  train  train  train
# chr8:12792429-12794543   train  train  train  train    val  train  train
# chr8:13629041-13631155   train  train  train  train    val  train  train
# ...                        ...    ...    ...    ...    ...    ...    ...
# chr19:23174666-23176780  train  train    val  train  train  train  train
# chr15:86727364-86729478  train  train  train  train  train  train  train
# chr19:23760587-23762701  train  train    val  train  train  train  train
# chr8:4165702-4167816     train  train  train  train    val  train  train
# chr8:10925678-10927792   train  train  train  train    val  train  train
#
# [54354 rows x 13 columns]

# %%
# %matplotlib inline
crested.pl.bar.normalization_weights(
    adata, title="Normalization Weights per Cell Type", x_label_rotation=90
)

# %%
outdir = f"../data/{experiment}/Hydropv2/"
os.makedirs(outdir, exist_ok=True)
adata.write_h5ad(os.path.join(outdir, "normalized.h5ad"))

# %%
crested.pp.filter_regions_on_specificity(adata, gini_std_threshold=1.0)
# Out:
# 2025-06-18T17:31:00.147651+0200 INFO After specificity filtering, kept 132078 out of 808843 regions.

# %%
adata.write_h5ad(os.path.join(outdir, "normalized_specific.h5ad"))

# %%
crested.pl.heatmap.correlations_self(
    adata,
    title="Self Correlation Heatmap HydropV2",
    x_label_rotation=90,
    width=8,
    height=8,
    vmax=1,
    log_transform=False,
    vmin=0.0,
)
